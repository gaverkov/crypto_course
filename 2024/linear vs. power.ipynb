# %%
PLOT = point([(x,(18*x + 7) % 101) for x in range(101)], color='red' , size = 30)
show(PLOT)
#PLOT.save_image('linear101.pdf')

PLOT = point( [(x, x^6 % 101) for x in range(101)], color='blue', size = 30)
show(PLOT)
#PLOT.save_image('power101.pdf')
# Out:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive
